# %%
import numpy as np
import matplotlib.pyplot as plt


steps=np.linspace(1e6,1e9,1000)

fx=np.loadtxt("/Users/changjin/Desktop/test.txt",skiprows=5)
t=fx[:,0]*1e9 #nano second

n=len(fx)
dt=(fx[1,0]-fx[0,0])
nu=np.fft.fftfreq(n,dt)
fk=np.fft.fft(fx[:,1])/n

plt.plot(nu,fk,'r')
plt.xlim(0,1e9)
plt.show()
# Out:
# /Users/changjin/anaconda/lib/python3.5/site-packages/numpy/core/numeric.py:482: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
